# %% [markdown]
# <a href="https://colab.research.google.com/github/adamsohjunior/SC3000-Artificial-Intelligence-/blob/main/cartpole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial and Sample Code for Balancing a Pole on a Cart

# %% [markdown]
# ## Installing dependencies:

# %%
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install gym[classic_control]
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# Out:
# Requirement already satisfied: gym[classic_control] in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym[classic_control]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym[classic_control]) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym[classic_control]) (0.0.8)
# Collecting pygame==2.1.0 (from gym[classic_control])
#   Downloading pygame-2.1.0.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 39.8 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (75.1.0)
# Collecting setuptools
#   Downloading setuptools-75.8.2-py3-none-any.whl.metadata (6.7 kB)
# Downloading setuptools-75.8.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed setuptools-75.8.2

# %%
# !apt-get update
# !apt-get install -y python3-pygame
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-freefont-ttf libfluidsynth3 libinstpatch-1.0-2 libmodplug1 libopusfile0 libportmidi0
#   libsdl2-image-2.0-0 libsdl2-mixer-2.0-0 libsdl2-ttf-2.0-0 python3-numpy timgm6mb-soundfont
# Suggested packages:
#   python-numpy-doc python3-pytest python-pygame-doc timidity fluid-soundfont-gm
# The following NEW packages will be installed:
#   fonts-freefont-ttf libfluidsynth3 libinstpatch-1.0-2 libmodplug1 libopusfile0 libportmidi0
#   libsdl2-image-2.0-0 libsdl2-mixer-2.0-0 libsdl2-ttf-2.0-0 python3-numpy python3-pygame
#   timgm6mb-soundfont
# 0 upgraded, 12 newly installed, 0 to remove and 31 not upgraded.
# Need to get 13.2 MB of archives.
# After this operation, 38.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodplug1 amd64 1:0.8.9.0-3 [153 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopusfile0 amd64 0.9+20170913-1.1build1 [43.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportmidi0 amd64 1:217-6 [17.8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-image-2.0-0 amd64 2.0.5+dfsg1-3build1 [70.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-mixer-2.0-0 amd64 2.0.4+dfsg1-4build1 [65.9 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl2-ttf-2.0-0 amd64 2.0.18+dfsg-2 [30.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-pygame amd64 2.1.2+dfsg-3 [1,089 kB]
# Fetched 13.2 MB in 1s (13.2 MB/s)
# Selecting previously unselected package fonts-freefont-ttf.
# (Reading database ... 124947 files and directories currently installed.)
# Preparing to unpack .../00-fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../01-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../02-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../03-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../04-libmodplug1_1%3a0.8.9.0-3_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-3) ...
# Selecting previously unselected package libopusfile0.
# Preparing to unpack .../05-libopusfile0_0.9+20170913-1.1build1_amd64.deb ...
# Unpacking libopusfile0 (0.9+20170913-1.1build1) ...
# Selecting previously unselected package libportmidi0:amd64.
# Preparing to unpack .../06-libportmidi0_1%3a217-6_amd64.deb ...
# Unpacking libportmidi0:amd64 (1:217-6) ...
# Selecting previously unselected package libsdl2-image-2.0-0:amd64.
# Preparing to unpack .../07-libsdl2-image-2.0-0_2.0.5+dfsg1-3build1_amd64.deb ...
# Unpacking libsdl2-image-2.0-0:amd64 (2.0.5+dfsg1-3build1) ...
# Selecting previously unselected package libsdl2-mixer-2.0-0:amd64.
# Preparing to unpack .../08-libsdl2-mixer-2.0-0_2.0.4+dfsg1-4build1_amd64.deb ...
# Unpacking libsdl2-mixer-2.0-0:amd64 (2.0.4+dfsg1-4build1) ...
# Selecting previously unselected package libsdl2-ttf-2.0-0:amd64.
# Preparing to unpack .../09-libsdl2-ttf-2.0-0_2.0.18+dfsg-2_amd64.deb ...
# Unpacking libsdl2-ttf-2.0-0:amd64 (2.0.18+dfsg-2) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../10-python3-numpy_1%3a1.21.5-1ubuntu22.04.1_amd64.deb ...
# Unpacking python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Selecting previously unselected package python3-pygame.
# Preparing to unpack .../11-python3-pygame_2.1.2+dfsg-3_amd64.deb ...
# Unpacking python3-pygame (2.1.2+dfsg-3) ...
# Setting up libsdl2-image-2.0-0:amd64 (2.0.5+dfsg1-3build1) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-3) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Setting up libportmidi0:amd64 (1:217-6) ...
# Setting up python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Setting up libsdl2-ttf-2.0-0:amd64 (2.0.18+dfsg-2) ...
# Setting up timgm6mb-soundfont (1.3-5) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up libopusfile0 (0.9+20170913-1.1build1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libsdl2-mixer-2.0-0:amd64 (2.0.4+dfsg1-4build1) ...
# Setting up python3-pygame (2.1.2+dfsg-3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# ## Importing dependencies and define helper functions

# %%
import gym
from gym import logger as gymlogger
from gym.wrappers import RecordVideo
gymlogger.set_level(40) #error only
import tensorflow as tf
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML
from IPython import display as ipythondisplay

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else:
    print("Could not find video")

# %% [markdown]
# Set up extra dependencies to be used later in the code implementation below.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque

# %% [markdown]
# ## Tutorial: Loading CartPole environment

# %%
env = gym.make("CartPole-v1")

# %% [markdown]
# We can check the action and observation space of this environment. Discrete(2) means that there are two valid discrete actions: 0 & 1.

# %%
print(env.action_space)
# Out:
# Discrete(2)

# %% [markdown]
# The observation space is given below. The first two arrays define the min and max values of the 4 observed values, corresponding to cart position, velocity and pole angle, angular velocity.

# %%
print(env.observation_space)
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %% [markdown]
# We call each round of the pole-balancing game an "episode". At the start of each episode, make sure the environment is reset, which chooses a random initial state, e.g., pole slightly tilted to the right. This initialization can be achieved by the code below, which returns the observation of the initial state.

# %%
observation = env.reset()
print("Initial observations:", observation)
# Out:
# Initial observations: [ 0.04886242  0.03683197 -0.01054026  0.03364755]

# %% [markdown]
# For the CartPole environment, there are two possible actions: 0 for pushing to the left and 1 for pushing to the right. For example, we can push the cart to the left using code below, which returns the new observation, the current reward, an indicator of whether the game ends, and some additional information (not used in this project). For CartPole, the game ends when the pole is significantly tilted or you manage to balance the pole for 500 steps. You get exactly 1 reward for each step before the game ends (i.e., max cumulative reward is 500).

# %%
observation, reward, done, info = env.step(0)
print("New observations after choosing action 0:", observation)
print("Reward for this step:", reward)
print("Is this round done?", done)
# Out:
# New observations after choosing action 0: [ 0.04959906 -0.15813726 -0.00986731  0.32298636]
# Reward for this step: 1.0
# Is this round done? False
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %% [markdown]
# Now we can play a full round of the game using a naive strategy (always choosing action 0), and show the cumulative reward in the round. Note that reward returned by env.step(*) corresponds to the reward for current step. So we have to accumulate the reward for each step. Clearly, the naive strategy performs poorly by surviving only a dozen of steps.

# %%
observation = env.reset()
cumulative_reward = 0
done = False
while not done:
    observation, reward, done, info = env.step(0)
    cumulative_reward += reward
print("Cumulative reward for this round:", cumulative_reward)
# Out:
# Cumulative reward for this round: 10.0

# %% [markdown]
# ## Task 1: Development of an RL agent

# %% [markdown]
# An example of a naive agent is given below,  which randomly chooses an action regardless of the observation:

# %%
def rand_policy_agent(observation):
    return random.randint(0, 1)

# %% [markdown]
# For the Reinforcement Learning (RL) agent, our team decides to go with **Deep Q-Network (DQN)** to balance the pole on the cart.
#
# 1. First, let us define the DQN Model.

# %%
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 256)  # Increased neurons
        self.fc2 = nn.Linear(256, 256)          # Added another layer
        self.fc3 = nn.Linear(256, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# 2. Next, we also define the Experience Replay Buffer. This will allow the agent to sample from these experiences randomly during training. This also help to break the correlation between consecutive experiences and stablilizes training.

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)  #automatically remove oldest experience if buffer is full

    def push(self, state, action, reward, next_state, done):   #Add new experience tuple into the buffer
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size): #randomly sample a batch of experiences from the buffer
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# 3. Next, we will set up the hyperparameters and intializes the key components of the DQN algorithm.

# %%
state_size = env.observation_space.shape[0] #size of state space, i.e. 4
print(state_size)
action_size = env.action_space.n  #number of possible actions, i.e. 2 (left and right)
print(action_size)
batch_size = 128          # Increased batch size
gamma = 0.99              # Discount factor (unchanged)
epsilon_start = 1.0       # Initial exploration rate
epsilon_end = 0.01        # Minimum exploration rate
epsilon_decay = 0.995     # Slower decay rate
target_update = 10        # Frequency of updating the target network
learning_rate = 0.00025    # Lower learning rate for stability

policy_net = DQN(state_size, action_size)
target_net = DQN(state_size, action_size)
target_net.load_state_dict(policy_net.state_dict())
optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)
buffer = ReplayBuffer(50000)
epsilon = epsilon_start
# Out:
# 4
# 2

# %% [markdown]
# 4. Once we finished the setup, we can train the agent now by interacting with the environment, collect experiences and update the neural network to improve its policy.

# %%
episode_rewards = []
best_reward = -float('inf')

for episode in range(1000):
    state = env.reset()
    total_reward = 0
    while True:
        # Epsilon-greedy action
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            with torch.no_grad():
                q_values = policy_net(torch.FloatTensor(state))
                action = q_values.argmax().item()

        # Take action
        next_state, reward, done, _ = env.step(action)
        total_reward += reward
        buffer.push(state, action, reward, next_state, done)

        # Train with Double DQN
        if len(buffer) >= batch_size:
            transitions = buffer.sample(batch_size)
            states, actions, rewards, next_states, dones = zip(*transitions)

            states = torch.FloatTensor(states)
            next_states = torch.FloatTensor(next_states)

            # Double DQN: Use policy net for action selection, target net for evaluation
            current_q = policy_net(states).gather(1, torch.LongTensor(actions).unsqueeze(1))
            next_actions = policy_net(next_states).argmax(1, keepdim=True)
            next_q = target_net(next_states).gather(1, next_actions).detach()

            target_q = torch.FloatTensor(rewards).unsqueeze(1) + gamma * next_q * (1 - torch.FloatTensor(dones).unsqueeze(1))

            # Huber loss for stability
            loss = nn.SmoothL1Loss()(current_q, target_q)

            optimizer.zero_grad()
            loss.backward()
            # Gradient clipping to prevent explosions
            torch.nn.utils.clip_grad_norm_(policy_net.parameters(), 1.0)
            optimizer.step()

        state = next_state
        if done:
            break

    # Decay epsilon and update target network
    epsilon = max(epsilon_end, epsilon * epsilon_decay)
    if episode % target_update == 0:
        target_net.load_state_dict(policy_net.state_dict())

    episode_rewards.append(total_reward)
    print(f"Episode {episode}, Reward: {total_reward}, Epsilon: {epsilon:.2f}")

    # Early stopping if agent solves the environment
    if total_reward >= 500:
        print("Early stopping: Agent solved the environment!")
        break
# Out:
# Episode 0, Reward: 40.0, Epsilon: 0.99
# Episode 1, Reward: 36.0, Epsilon: 0.99
# Episode 2, Reward: 30.0, Epsilon: 0.99
# Episode 3, Reward: 33.0, Epsilon: 0.98
# <ipython-input-14-b24122031626>:26: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   states = torch.FloatTensor(states)
# Episode 4, Reward: 30.0, Epsilon: 0.98
# Episode 5, Reward: 26.0, Epsilon: 0.97
# Episode 6, Reward: 24.0, Epsilon: 0.97
# Episode 7, Reward: 18.0, Epsilon: 0.96
# Episode 8, Reward: 12.0, Epsilon: 0.96
# Episode 9, Reward: 22.0, Epsilon: 0.95
# Episode 10, Reward: 14.0, Epsilon: 0.95
# Episode 11, Reward: 20.0, Epsilon: 0.94
# Episode 12, Reward: 45.0, Epsilon: 0.94
# Episode 13, Reward: 29.0, Epsilon: 0.93
# Episode 14, Reward: 17.0, Epsilon: 0.93
# Episode 15, Reward: 38.0, Epsilon: 0.92
# Episode 16, Reward: 20.0, Epsilon: 0.92
# Episode 17, Reward: 16.0, Epsilon: 0.91
# Episode 18, Reward: 14.0, Epsilon: 0.91
# Episode 19, Reward: 15.0, Epsilon: 0.90
# Episode 20, Reward: 21.0, Epsilon: 0.90
# Episode 21, Reward: 15.0, Epsilon: 0.90
# Episode 22, Reward: 10.0, Epsilon: 0.89
# Episode 23, Reward: 22.0, Epsilon: 0.89
# Episode 24, Reward: 16.0, Epsilon: 0.88
# Episode 25, Reward: 12.0, Epsilon: 0.88
# Episode 26, Reward: 28.0, Epsilon: 0.87
# Episode 27, Reward: 31.0, Epsilon: 0.87
# Episode 28, Reward: 20.0, Epsilon: 0.86
# Episode 29, Reward: 13.0, Epsilon: 0.86
# Episode 30, Reward: 37.0, Epsilon: 0.86
# Episode 31, Reward: 26.0, Epsilon: 0.85
# Episode 32, Reward: 25.0, Epsilon: 0.85
# Episode 33, Reward: 27.0, Epsilon: 0.84
# Episode 34, Reward: 22.0, Epsilon: 0.84
# Episode 35, Reward: 22.0, Epsilon: 0.83
# Episode 36, Reward: 15.0, Epsilon: 0.83
# Episode 37, Reward: 29.0, Epsilon: 0.83
# Episode 38, Reward: 13.0, Epsilon: 0.82
# Episode 39, Reward: 18.0, Epsilon: 0.82
# Episode 40, Reward: 15.0, Epsilon: 0.81
# Episode 41, Reward: 41.0, Epsilon: 0.81
# Episode 42, Reward: 12.0, Epsilon: 0.81
# Episode 43, Reward: 22.0, Epsilon: 0.80
# Episode 44, Reward: 16.0, Epsilon: 0.80
# Episode 45, Reward: 17.0, Epsilon: 0.79
# Episode 46, Reward: 12.0, Epsilon: 0.79
# Episode 47, Reward: 59.0, Epsilon: 0.79
# Episode 48, Reward: 42.0, Epsilon: 0.78
# Episode 49, Reward: 12.0, Epsilon: 0.78
# Episode 50, Reward: 45.0, Epsilon: 0.77
# Episode 51, Reward: 33.0, Epsilon: 0.77
# Episode 52, Reward: 42.0, Epsilon: 0.77
# Episode 53, Reward: 11.0, Epsilon: 0.76
# Episode 54, Reward: 87.0, Epsilon: 0.76
# Episode 55, Reward: 36.0, Epsilon: 0.76
# Episode 56, Reward: 52.0, Epsilon: 0.75
# Episode 57, Reward: 43.0, Epsilon: 0.75
# Episode 58, Reward: 15.0, Epsilon: 0.74
# Episode 59, Reward: 73.0, Epsilon: 0.74
# Episode 60, Reward: 17.0, Epsilon: 0.74
# Episode 61, Reward: 18.0, Epsilon: 0.73
# Episode 62, Reward: 40.0, Epsilon: 0.73
# Episode 63, Reward: 40.0, Epsilon: 0.73
# Episode 64, Reward: 11.0, Epsilon: 0.72
# Episode 65, Reward: 19.0, Epsilon: 0.72
# Episode 66, Reward: 29.0, Epsilon: 0.71
# Episode 67, Reward: 16.0, Epsilon: 0.71
# Episode 68, Reward: 51.0, Epsilon: 0.71
# Episode 69, Reward: 23.0, Epsilon: 0.70
# Episode 70, Reward: 44.0, Epsilon: 0.70
# Episode 71, Reward: 39.0, Epsilon: 0.70
# Episode 72, Reward: 11.0, Epsilon: 0.69
# Episode 73, Reward: 24.0, Epsilon: 0.69
# Episode 74, Reward: 98.0, Epsilon: 0.69
# Episode 75, Reward: 48.0, Epsilon: 0.68
# Episode 76, Reward: 19.0, Epsilon: 0.68
# Episode 77, Reward: 91.0, Epsilon: 0.68
# Episode 78, Reward: 22.0, Epsilon: 0.67
# Episode 79, Reward: 60.0, Epsilon: 0.67
# Episode 80, Reward: 66.0, Epsilon: 0.67
# Episode 81, Reward: 28.0, Epsilon: 0.66
# Episode 82, Reward: 17.0, Epsilon: 0.66
# Episode 83, Reward: 43.0, Epsilon: 0.66
# Episode 84, Reward: 34.0, Epsilon: 0.65
# Episode 85, Reward: 20.0, Epsilon: 0.65
# Episode 86, Reward: 21.0, Epsilon: 0.65
# Episode 87, Reward: 20.0, Epsilon: 0.64
# Episode 88, Reward: 45.0, Epsilon: 0.64
# Episode 89, Reward: 47.0, Epsilon: 0.64
# Episode 90, Reward: 119.0, Epsilon: 0.63
# Episode 91, Reward: 75.0, Epsilon: 0.63
# Episode 92, Reward: 34.0, Epsilon: 0.63
# Episode 93, Reward: 42.0, Epsilon: 0.62
# Episode 94, Reward: 15.0, Epsilon: 0.62
# Episode 95, Reward: 78.0, Epsilon: 0.62
# Episode 96, Reward: 16.0, Epsilon: 0.61
# Episode 97, Reward: 57.0, Epsilon: 0.61
# Episode 98, Reward: 81.0, Epsilon: 0.61
# Episode 99, Reward: 37.0, Epsilon: 0.61
# Episode 100, Reward: 37.0, Epsilon: 0.60
# Episode 101, Reward: 19.0, Epsilon: 0.60
# Episode 102, Reward: 39.0, Epsilon: 0.60
# Episode 103, Reward: 124.0, Epsilon: 0.59
# Episode 104, Reward: 78.0, Epsilon: 0.59
# Episode 105, Reward: 38.0, Epsilon: 0.59
# Episode 106, Reward: 146.0, Epsilon: 0.58
# Episode 107, Reward: 46.0, Epsilon: 0.58
# Episode 108, Reward: 63.0, Epsilon: 0.58
# Episode 109, Reward: 45.0, Epsilon: 0.58
# Episode 110, Reward: 19.0, Epsilon: 0.57
# Episode 111, Reward: 94.0, Epsilon: 0.57
# Episode 112, Reward: 52.0, Epsilon: 0.57
# Episode 113, Reward: 53.0, Epsilon: 0.56
# Episode 114, Reward: 17.0, Epsilon: 0.56
# Episode 115, Reward: 73.0, Epsilon: 0.56
# Episode 116, Reward: 36.0, Epsilon: 0.56
# Episode 117, Reward: 113.0, Epsilon: 0.55
# Episode 118, Reward: 53.0, Epsilon: 0.55
# Episode 119, Reward: 22.0, Epsilon: 0.55
# Episode 120, Reward: 17.0, Epsilon: 0.55
# Episode 121, Reward: 46.0, Epsilon: 0.54
# Episode 122, Reward: 162.0, Epsilon: 0.54
# Episode 123, Reward: 55.0, Epsilon: 0.54
# Episode 124, Reward: 10.0, Epsilon: 0.53
# Episode 125, Reward: 31.0, Epsilon: 0.53
# Episode 126, Reward: 56.0, Epsilon: 0.53
# Episode 127, Reward: 101.0, Epsilon: 0.53
# Episode 128, Reward: 64.0, Epsilon: 0.52
# Episode 129, Reward: 25.0, Epsilon: 0.52
# Episode 130, Reward: 32.0, Epsilon: 0.52
# Episode 131, Reward: 26.0, Epsilon: 0.52
# Episode 132, Reward: 44.0, Epsilon: 0.51
# Episode 133, Reward: 58.0, Epsilon: 0.51
# Episode 134, Reward: 100.0, Epsilon: 0.51
# Episode 135, Reward: 115.0, Epsilon: 0.51
# Episode 136, Reward: 19.0, Epsilon: 0.50
# Episode 137, Reward: 143.0, Epsilon: 0.50
# Episode 138, Reward: 231.0, Epsilon: 0.50
# Episode 139, Reward: 152.0, Epsilon: 0.50
# Episode 140, Reward: 25.0, Epsilon: 0.49
# Episode 141, Reward: 13.0, Epsilon: 0.49
# Episode 142, Reward: 40.0, Epsilon: 0.49
# Episode 143, Reward: 135.0, Epsilon: 0.49
# Episode 144, Reward: 88.0, Epsilon: 0.48
# Episode 145, Reward: 170.0, Epsilon: 0.48
# Episode 146, Reward: 43.0, Epsilon: 0.48
# Episode 147, Reward: 95.0, Epsilon: 0.48
# Episode 148, Reward: 150.0, Epsilon: 0.47
# Episode 149, Reward: 45.0, Epsilon: 0.47
# Episode 150, Reward: 56.0, Epsilon: 0.47
# Episode 151, Reward: 61.0, Epsilon: 0.47
# Episode 152, Reward: 26.0, Epsilon: 0.46
# Episode 153, Reward: 103.0, Epsilon: 0.46
# Episode 154, Reward: 69.0, Epsilon: 0.46
# Episode 155, Reward: 58.0, Epsilon: 0.46
# Episode 156, Reward: 44.0, Epsilon: 0.46
# Episode 157, Reward: 153.0, Epsilon: 0.45
# Episode 158, Reward: 129.0, Epsilon: 0.45
# Episode 159, Reward: 35.0, Epsilon: 0.45
# Episode 160, Reward: 134.0, Epsilon: 0.45
# Episode 161, Reward: 127.0, Epsilon: 0.44
# Episode 162, Reward: 33.0, Epsilon: 0.44
# Episode 163, Reward: 115.0, Epsilon: 0.44
# Episode 164, Reward: 12.0, Epsilon: 0.44
# Episode 165, Reward: 17.0, Epsilon: 0.44
# Episode 166, Reward: 30.0, Epsilon: 0.43
# Episode 167, Reward: 75.0, Epsilon: 0.43
# Episode 168, Reward: 131.0, Epsilon: 0.43
# Episode 169, Reward: 85.0, Epsilon: 0.43
# Episode 170, Reward: 17.0, Epsilon: 0.42
# Episode 171, Reward: 134.0, Epsilon: 0.42
# Episode 172, Reward: 56.0, Epsilon: 0.42
# Episode 173, Reward: 32.0, Epsilon: 0.42
# Episode 174, Reward: 9.0, Epsilon: 0.42
# Episode 175, Reward: 28.0, Epsilon: 0.41
# Episode 176, Reward: 153.0, Epsilon: 0.41
# Episode 177, Reward: 121.0, Epsilon: 0.41
# Episode 178, Reward: 18.0, Epsilon: 0.41
# Episode 179, Reward: 129.0, Epsilon: 0.41
# Episode 180, Reward: 130.0, Epsilon: 0.40
# Episode 181, Reward: 130.0, Epsilon: 0.40
# Episode 182, Reward: 10.0, Epsilon: 0.40
# Episode 183, Reward: 125.0, Epsilon: 0.40
# Episode 184, Reward: 32.0, Epsilon: 0.40
# Episode 185, Reward: 19.0, Epsilon: 0.39
# Episode 186, Reward: 62.0, Epsilon: 0.39
# Episode 187, Reward: 24.0, Epsilon: 0.39
# Episode 188, Reward: 57.0, Epsilon: 0.39
# Episode 189, Reward: 65.0, Epsilon: 0.39
# Episode 190, Reward: 15.0, Epsilon: 0.38
# Episode 191, Reward: 117.0, Epsilon: 0.38
# Episode 192, Reward: 110.0, Epsilon: 0.38
# Episode 193, Reward: 86.0, Epsilon: 0.38
# Episode 194, Reward: 105.0, Epsilon: 0.38
# Episode 195, Reward: 102.0, Epsilon: 0.37
# Episode 196, Reward: 15.0, Epsilon: 0.37
# Episode 197, Reward: 124.0, Epsilon: 0.37
# Episode 198, Reward: 13.0, Epsilon: 0.37
# Episode 199, Reward: 15.0, Epsilon: 0.37
# Episode 200, Reward: 125.0, Epsilon: 0.37
# Episode 201, Reward: 60.0, Epsilon: 0.36
# Episode 202, Reward: 145.0, Epsilon: 0.36
# Episode 203, Reward: 13.0, Epsilon: 0.36
# Episode 204, Reward: 13.0, Epsilon: 0.36
# Episode 205, Reward: 23.0, Epsilon: 0.36
# Episode 206, Reward: 14.0, Epsilon: 0.35
# Episode 207, Reward: 18.0, Epsilon: 0.35
# Episode 208, Reward: 15.0, Epsilon: 0.35
# Episode 209, Reward: 179.0, Epsilon: 0.35
# Episode 210, Reward: 133.0, Epsilon: 0.35
# Episode 211, Reward: 10.0, Epsilon: 0.35
# Episode 212, Reward: 16.0, Epsilon: 0.34
# Episode 213, Reward: 19.0, Epsilon: 0.34
# Episode 214, Reward: 14.0, Epsilon: 0.34
# Episode 215, Reward: 115.0, Epsilon: 0.34
# Episode 216, Reward: 140.0, Epsilon: 0.34
# Episode 217, Reward: 14.0, Epsilon: 0.34
# Episode 218, Reward: 19.0, Epsilon: 0.33
# Episode 219, Reward: 43.0, Epsilon: 0.33
# Episode 220, Reward: 17.0, Epsilon: 0.33
# Episode 221, Reward: 148.0, Epsilon: 0.33
# Episode 222, Reward: 14.0, Epsilon: 0.33
# Episode 223, Reward: 164.0, Epsilon: 0.33
# Episode 224, Reward: 10.0, Epsilon: 0.32
# Episode 225, Reward: 21.0, Epsilon: 0.32
# Episode 226, Reward: 145.0, Epsilon: 0.32
# Episode 227, Reward: 178.0, Epsilon: 0.32
# Episode 228, Reward: 73.0, Epsilon: 0.32
# Episode 229, Reward: 47.0, Epsilon: 0.32
# Episode 230, Reward: 182.0, Epsilon: 0.31
# Episode 231, Reward: 175.0, Epsilon: 0.31
# Episode 232, Reward: 94.0, Epsilon: 0.31
# Episode 233, Reward: 14.0, Epsilon: 0.31
# Episode 234, Reward: 143.0, Epsilon: 0.31
# Episode 235, Reward: 207.0, Epsilon: 0.31
# Episode 236, Reward: 188.0, Epsilon: 0.30
# Episode 237, Reward: 69.0, Epsilon: 0.30
# Episode 238, Reward: 198.0, Epsilon: 0.30
# Episode 239, Reward: 51.0, Epsilon: 0.30
# Episode 240, Reward: 288.0, Epsilon: 0.30
# Episode 241, Reward: 113.0, Epsilon: 0.30
# Episode 242, Reward: 352.0, Epsilon: 0.30
# Episode 243, Reward: 166.0, Epsilon: 0.29
# Episode 244, Reward: 127.0, Epsilon: 0.29
# Episode 245, Reward: 180.0, Epsilon: 0.29
# Episode 246, Reward: 197.0, Epsilon: 0.29
# Episode 247, Reward: 32.0, Epsilon: 0.29
# Episode 248, Reward: 179.0, Epsilon: 0.29
# Episode 249, Reward: 187.0, Epsilon: 0.29
# Episode 250, Reward: 13.0, Epsilon: 0.28
# Episode 251, Reward: 13.0, Epsilon: 0.28
# Episode 252, Reward: 114.0, Epsilon: 0.28
# Episode 253, Reward: 14.0, Epsilon: 0.28
# Episode 254, Reward: 224.0, Epsilon: 0.28
# Episode 255, Reward: 219.0, Epsilon: 0.28
# Episode 256, Reward: 157.0, Epsilon: 0.28
# Episode 257, Reward: 208.0, Epsilon: 0.27
# Episode 258, Reward: 148.0, Epsilon: 0.27
# Episode 259, Reward: 223.0, Epsilon: 0.27
# Episode 260, Reward: 83.0, Epsilon: 0.27
# Episode 261, Reward: 33.0, Epsilon: 0.27
# Episode 262, Reward: 30.0, Epsilon: 0.27
# Episode 263, Reward: 163.0, Epsilon: 0.27
# Episode 264, Reward: 196.0, Epsilon: 0.26
# Episode 265, Reward: 173.0, Epsilon: 0.26
# Episode 266, Reward: 106.0, Epsilon: 0.26
# Episode 267, Reward: 252.0, Epsilon: 0.26
# Episode 268, Reward: 50.0, Epsilon: 0.26
# Episode 269, Reward: 170.0, Epsilon: 0.26
# Episode 270, Reward: 12.0, Epsilon: 0.26
# Episode 271, Reward: 13.0, Epsilon: 0.26
# Episode 272, Reward: 13.0, Epsilon: 0.25
# Episode 273, Reward: 183.0, Epsilon: 0.25
# Episode 274, Reward: 16.0, Epsilon: 0.25
# Episode 275, Reward: 11.0, Epsilon: 0.25
# Episode 276, Reward: 161.0, Epsilon: 0.25
# Episode 277, Reward: 100.0, Epsilon: 0.25
# Episode 278, Reward: 11.0, Epsilon: 0.25
# Episode 279, Reward: 106.0, Epsilon: 0.25
# Episode 280, Reward: 103.0, Epsilon: 0.24
# Episode 281, Reward: 19.0, Epsilon: 0.24
# Episode 282, Reward: 11.0, Epsilon: 0.24
# Episode 283, Reward: 20.0, Epsilon: 0.24
# Episode 284, Reward: 13.0, Epsilon: 0.24
# Episode 285, Reward: 106.0, Epsilon: 0.24
# Episode 286, Reward: 116.0, Epsilon: 0.24
# Episode 287, Reward: 129.0, Epsilon: 0.24
# Episode 288, Reward: 112.0, Epsilon: 0.23
# Episode 289, Reward: 18.0, Epsilon: 0.23
# Episode 290, Reward: 142.0, Epsilon: 0.23
# Episode 291, Reward: 114.0, Epsilon: 0.23
# Episode 292, Reward: 117.0, Epsilon: 0.23
# Episode 293, Reward: 19.0, Epsilon: 0.23
# Episode 294, Reward: 62.0, Epsilon: 0.23
# Episode 295, Reward: 15.0, Epsilon: 0.23
# Episode 296, Reward: 104.0, Epsilon: 0.23
# Episode 297, Reward: 19.0, Epsilon: 0.22
# Episode 298, Reward: 12.0, Epsilon: 0.22
# Episode 299, Reward: 114.0, Epsilon: 0.22
# Episode 300, Reward: 99.0, Epsilon: 0.22
# Episode 301, Reward: 16.0, Epsilon: 0.22
# Episode 302, Reward: 158.0, Epsilon: 0.22
# Episode 303, Reward: 148.0, Epsilon: 0.22
# Episode 304, Reward: 303.0, Epsilon: 0.22
# Episode 305, Reward: 35.0, Epsilon: 0.22
# Episode 306, Reward: 125.0, Epsilon: 0.21
# Episode 307, Reward: 152.0, Epsilon: 0.21
# Episode 308, Reward: 13.0, Epsilon: 0.21
# Episode 309, Reward: 155.0, Epsilon: 0.21
# Episode 310, Reward: 34.0, Epsilon: 0.21
# Episode 311, Reward: 120.0, Epsilon: 0.21
# Episode 312, Reward: 155.0, Epsilon: 0.21
# Episode 313, Reward: 21.0, Epsilon: 0.21
# Episode 314, Reward: 306.0, Epsilon: 0.21
# Episode 315, Reward: 332.0, Epsilon: 0.21
# Episode 316, Reward: 153.0, Epsilon: 0.20
# Episode 317, Reward: 33.0, Epsilon: 0.20
# Episode 318, Reward: 59.0, Epsilon: 0.20
# Episode 319, Reward: 25.0, Epsilon: 0.20
# Episode 320, Reward: 139.0, Epsilon: 0.20
# Episode 321, Reward: 325.0, Epsilon: 0.20
# Episode 322, Reward: 65.0, Epsilon: 0.20
# Episode 323, Reward: 218.0, Epsilon: 0.20
# Episode 324, Reward: 173.0, Epsilon: 0.20
# Episode 325, Reward: 78.0, Epsilon: 0.20
# Episode 326, Reward: 177.0, Epsilon: 0.19
# Episode 327, Reward: 411.0, Epsilon: 0.19
# Episode 328, Reward: 111.0, Epsilon: 0.19
# Episode 329, Reward: 24.0, Epsilon: 0.19
# Episode 330, Reward: 126.0, Epsilon: 0.19
# Episode 331, Reward: 56.0, Epsilon: 0.19
# Episode 332, Reward: 336.0, Epsilon: 0.19
# Episode 333, Reward: 14.0, Epsilon: 0.19
# Episode 334, Reward: 36.0, Epsilon: 0.19
# Episode 335, Reward: 376.0, Epsilon: 0.19
# Episode 336, Reward: 22.0, Epsilon: 0.18
# Episode 337, Reward: 261.0, Epsilon: 0.18
# Episode 338, Reward: 44.0, Epsilon: 0.18
# Episode 339, Reward: 500.0, Epsilon: 0.18
# Early stopping: Agent solved the environment!

# %% [markdown]
# 5. After training with the environment, we can demonstrate that the agent can take a state (observation) from the environment and output a valid action.

# %%
# Load trained policy_net (after training)
state = env.reset()
with torch.no_grad():
    q_values = policy_net(torch.FloatTensor(state))
    action = q_values.argmax().item()
print("Observation:", state)
print("Chosen action:", action)
# Out:
# Observation: [ 0.01032667  0.00897658 -0.021994   -0.02969156]
# Chosen action: 0

# %% [markdown]
# Task 2: Evaluate Over 100 episodes

# %%
episode_results = []
for _ in range(100):
    state = env.reset()
    total_reward = 0
    while True:
        with torch.no_grad():
            q_values = policy_net(torch.FloatTensor(state))
            action = q_values.argmax().item()
        state, reward, done, _ = env.step(action)
        total_reward += reward
        if done:
            break
    episode_results.append(total_reward)

plt.plot(episode_results)
plt.title('Cumulative Reward for Each Episode')
plt.ylabel('Cumulative Reward')
plt.xlabel('Episode')
plt.show()

average_reward = np.mean(episode_results)
print(f"Average cumulative reward: {average_reward:.2f}")
print("Is my agent good enough?", average_reward > 195)
# Out:
# Average cumulative reward: 338.17
# Is my agent good enough? True

# %% [markdown]
# For Task 1, we can show the observation and chosen action below:

# %%
observation = env.reset()
action = rand_policy_agent(observation)
print("Observation:", observation)
print("Chosen action:", action)
# Out:
# Observation: [ 0.02565273 -0.00383895 -0.01032397 -0.00787272]
# Chosen action: 0

# %% [markdown]
# ## Task 2: Demonstrate the effectiveness of the RL agent

# %% [markdown]
# For this task, use the agent developed in Task 1 to play the game for 100 episodes (refer to tutorial for how to play a round), record the cumulative reward for each round, and plot the reward for each round. A sample plotting code is given below. Note that you must include code to play for 100 episodes and use the code to obtain round_results for plotting. DO NOT record the round results in advance and paste the results to the notebook.

# %%
episode_results = np.random.randint(150, 250, size=100)
plt.plot(episode_results)
plt.title('Cumulative reward for each episode')
plt.ylabel('Cumulative reward')
plt.xlabel('episode')
plt.show()

# %% [markdown]
# Print the average reward over the 100 episodes.

# %%
print("Average cumulative reward:", episode_results.mean())
print("Is my agent good enough?", episode_results.mean() > 195)
# Out:
# Average cumulative reward: 199.7
# Is my agent good enough? True

# %% [markdown]
# ## Task 3: Render one episode played by the agent

# %% [markdown]
# Plug your agent to the code below to obtain rendered result.

# %%
random.seed(100)
policy_net.eval()  # Set network to evaluation mode

# Create environment with video recording
env = RecordVideo(gym.make("CartPole-v1"), "./video")
observation = env.reset()

while True:
    # Get action from trained agent
    with torch.no_grad():
        q_values = policy_net(torch.FloatTensor(observation))
        action = q_values.argmax().item()

    # Take the chosen action
    observation, reward, done, info = env.step(action)

    if done:
        break

env.close()
show_video()
# Out:
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3147: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3147: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3147: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
